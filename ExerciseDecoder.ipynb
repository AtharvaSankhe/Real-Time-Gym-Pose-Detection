# %% [markdown]
# # 0. Import Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow 
import math

from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, classification_report
from tensorflow.keras.utils import to_categorical

import tensorflow 
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from tensorflow.keras.models import Sequential, Model

from tensorflow.keras.layers import (LSTM, Dense, Concatenate, Attention, Dropout, Softmax,
                                     Input, Flatten, Activation, Bidirectional, Permute, multiply, 
                                     ConvLSTM2D, MaxPooling3D, TimeDistributed, Conv2D, MaxPooling2D)

from scipy import stats

# disable some of the tf/keras training warnings 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "3"
tensorflow.get_logger().setLevel("ERROR")
tensorflow.autograph.set_verbosity(1)

# suppress untraced functions warning
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %% [markdown]
# # 1. Keypoints using MP Pose

# %%
# Pre-trained pose estimation model from Google Mediapipe
mp_pose = mp.solutions.pose

# Supported Mediapipe visualization tools
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    """
    This function detects human pose estimation keypoints from webcam footage
    
    """
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    """
    This function draws keypoints and landmarks detected by the human pose estimation model
    
    """
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )

# %%
cap = cv2.VideoCapture(0) # camera object
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

# Set and test mediapipe model using webcam
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
      
        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
        except:
            pass
        
        # Render detections
        draw_landmarks(image, results)               
        
        # Display frame on screen
        cv2.imshow('OpenCV Feed', image)
        
        # Exit / break out logic
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
print(len(results.pose_landmarks.landmark))
# Out:
# 33

# %% [markdown]
# # 2. Extract Keypoints

# %%
# Recollect and organize keypoints from the test
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
print(len(pose))
# Out:
# 33

# %%
# 33 landmarks with 4 values (x, y, z, visibility)
num_landmarks = len(landmarks)
num_values = len(test)
num_input_values = num_landmarks*num_values
num_input_values
# Out:
# 132

# %%
# This is an example of what we would use as an input into our AI models
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)

# %%
def extract_keypoints(results):
    """
    Processes and organizes the keypoints detected from the pose estimation model 
    to be used as inputs for the exercise decoder models
    
    """
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    return pose

# %% [markdown]
# # 3. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join(os. getcwd(),'data') 
print(DATA_PATH)

# make directory if it does not exist yet
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# Actions/exercises that we try to detect
actions = np.array(['Bench Press','PushUp','Barbell Biceps Curl','Leg Raises','Shoulder Press','Squat'])
# actions = np.array(['squat'])
num_classes = len(actions)

# How many videos worth of data
no_sequences = 13

# Videos are going to be this many frames in length
sequence_length = FPS*1

# Folder start
# Change this to collect more data and not lose previously collected data
start_folder = 101
# Out:
# e:\openCV\lstm\Exercise_Recognition_AI\data

# %%
# Build folder paths
for action in actions:     
    for sequence in range(start_folder,no_sequences+start_folder):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))  
        except:
            pass

# %%
# import os
# import cv2

# # Directory containing video files
# video_folder = "squat"  # Replace with the actual folder path

# # Output video file name
# output_video_file = "squats.mp4"

# # List to store video files in the folder
# video_files = []

# # Get a list of video files in the folder
# for filename in os.listdir(video_folder):
#     if filename.endswith(".mp4") or filename.endswith(".avi"):
#         video_files.append(os.path.join(video_folder, filename))

# # Check if there are video files to combine
# if not video_files:
#     print("No video files found in the folder.")
# else:
#     # Get the properties of the first video file to use as a template
#     first_video = cv2.VideoCapture(video_files[0])
#     frame_width = int(first_video.get(3))
#     frame_height = int(first_video.get(4))

#     # Define the codec and create a VideoWriter object
#     fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # You can change the codec as needed
#     out = cv2.VideoWriter(output_video_file, fourcc, 30.0, (frame_width, frame_height))

#     # Iterate through video files and combine them
#     for video_file in video_files:
#         video = cv2.VideoCapture(video_file)
#         while True:
#             ret, frame = video.read()
#             if not ret:
#                 break
#             out.write(frame)

#         video.release()

#     out.release()
#     print(f"Combined video saved as {output_video_file}")
# no need of this code
# Out:
# Combined video saved as squats.mp4

# %% [markdown]
# # 4. Collect Keypoint Values for Training and Testing

# %%
# Colors associated with each exercise (e.g., curls are denoted by blue, squats are denoted by orange, etc.)
colors = [(245,117,16), (117,245,16), (16,117,245),(255,0,255),(0,255,255),(255,255,0)]

# %%
# # Collect Training Data
# # while True:
# #     ret, frame = cap.read()

# cap = cv2.VideoCapture('squats.mp4')
# # Set mediapipe model 
# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#     # Loop through actions
#     for idx, action in enumerate(actions):
#         # Loop through sequences (i.e., videos)
#         for sequence in range(start_folder, start_folder+no_sequences):
#             # Loop through video length (i.e, sequence length)
#             for frame_num in range(sequence_length):
#                 # Read feed
#                 ret, frame = cap.read()
                
#                 # Make detection
#                 image, results = mediapipe_detection(frame, pose)

#                 # Extract landmarks
#                 try:
#                     landmarks = results.pose_landmarks.landmark
#                 except:
#                     pass
                
#                 # Render detections
#                 draw_landmarks(image, results) 

#                 # Apply visualization logic
#                 if frame_num == 0: # If first frame in sequence, print that you're starting a new data collection and wait 500 ms
#                     cv2.putText(image, 'STARTING COLLECTION', (120,200), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    
#                     cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
#                     cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
#                     cv2.waitKey(500)
#                 else: 
#                     cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
#                     cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)

#                 # Export keypoints (sequence + pose landmarks)
#                 keypoints = extract_keypoints(results)
#                 npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
#                 np.save(npy_path, keypoints)

#                 # Break gracefully
#                 if cv2.waitKey(10) & 0xFF == ord('q'):
#                     break
                    
#     cap.release()
#     cv2.destroyAllWindows()

# # save data from videos   CORRECT ONE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7724\929247130.py in <module>
#       3 #     ret, frame = cap.read()
#       4
# ----> 5 cap = cv2.VideoCapture('squats.mp4')
#       6 # Set mediapipe model
#       7 with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#
# NameError: name 'cv2' is not defined

# %%
video_paths = []
for workout in actions:
    for video_file in os.listdir(workout):
        video_paths.append(f'{workout}\{video_file}')

# %%
video_paths
# Out:
# ['Bench Press\\bench press_1.mp4',
#  'Bench Press\\bench press_10.mp4',
#  'Bench Press\\bench press_11.mp4',
#  'Bench Press\\bench press_12.mp4',
#  'Bench Press\\bench press_13.mp4',
#  'Bench Press\\bench press_14.mp4',
#  'Bench Press\\bench press_15.mp4',
#  'Bench Press\\bench press_16.mp4',
#  'Bench Press\\bench press_17.mp4',
#  'Bench Press\\bench press_2.mp4',
#  'Bench Press\\bench press_3.mp4',
#  'Bench Press\\bench press_4.mp4',
#  'Bench Press\\bench press_5.mp4',
#  'Bench Press\\bench press_6.mp4',
#  'Bench Press\\bench press_7.mp4',
#  'Bench Press\\bench press_8.mp4',
#  'Bench Press\\bench press_9.mp4',
#  'PushUp\\push-up_1.mp4',
#  'PushUp\\push-up_10.mp4',
#  'PushUp\\push-up_11.mp4',
#  'PushUp\\push-up_12.mp4',
#  'PushUp\\push-up_13.mp4',
#  'PushUp\\push-up_14.mp4',
#  'PushUp\\push-up_15.mp4',
#  'PushUp\\push-up_16.mp4',
#  'PushUp\\push-up_17.mp4',
#  'PushUp\\push-up_2.mp4',
#  'PushUp\\push-up_3.mp4',
#  'PushUp\\push-up_4.mp4',
#  'PushUp\\push-up_5.mp4',
#  'PushUp\\push-up_6.mp4',
#  'PushUp\\push-up_7.mp4',
#  'PushUp\\push-up_8.mp4',
#  'PushUp\\push-up_9.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_1.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_10.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_11.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_12.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_13.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_14.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_15.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_16.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_17.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_2.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_3.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_4.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_5.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_6.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_7.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_8.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_9.mp4',
#  'Lateral Raises\\lateral raise_1.MOV',
#  'Lateral Raises\\lateral raise_10.mp4',
#  'Lateral Raises\\lateral raise_11.mp4',
#  'Lateral Raises\\lateral raise_12.mp4',
#  'Lateral Raises\\lateral raise_13.mp4',
#  'Lateral Raises\\lateral raise_14.mp4',
#  'Lateral Raises\\lateral raise_15.mp4',
#  'Lateral Raises\\lateral raise_16.mp4',
#  'Lateral Raises\\lateral raise_17.mp4',
#  'Lateral Raises\\lateral raise_2.MOV',
#  'Lateral Raises\\lateral raise_3.MOV',
#  'Lateral Raises\\lateral raise_4.MOV',
#  'Lateral Raises\\lateral raise_5.MOV',
#  'Lateral Raises\\lateral raise_6.MOV',
#  'Lateral Raises\\lateral raise_7.mp4',
#  'Lateral Raises\\lateral raise_8.mp4',
#  'Lateral Raises\\lateral raise_9.mp4',
#  'Shoulder Press\\shoulder press_1.MOV',
#  'Shoulder Press\\shoulder press_10.mp4',
#  'Shoulder Press\\shoulder press_11.mp4',
#  'Shoulder Press\\shoulder press_12.mp4',
#  'Shoulder Press\\shoulder press_13.mp4',
#  'Shoulder Press\\shoulder press_14.mp4',
#  'Shoulder Press\\shoulder press_15.mp4',
#  'Shoulder Press\\shoulder press_16.mp4',
#  'Shoulder Press\\shoulder press_17.mp4',
#  'Shoulder Press\\shoulder press_2.MOV',
#  'Shoulder Press\\shoulder press_3.MOV',
#  'Shoulder Press\\shoulder press_4.MOV',
#  'Shoulder Press\\shoulder press_5.mp4',
#  'Shoulder Press\\shoulder press_6.mp4',
#  'Shoulder Press\\shoulder press_7.mp4',
#  'Shoulder Press\\shoulder press_8.mp4',
#  'Shoulder Press\\shoulder press_9.mp4',
#  'Squat\\squat_10.mp4',
#  'Squat\\squat_11.mp4',
#  'Squat\\squat_12.mp4',
#  'Squat\\squat_13.mp4',
#  'Squat\\squat_14.mp4',
#  'Squat\\squat_15.mp4',
#  'Squat\\squat_16.mp4',
#  'Squat\\squat_17.mp4',
#  'Squat\\squat_18.mp4',
#  'Squat\\squat_19.mp4',
#  'Squat\\squat_20.mp4',
#  'Squat\\squat_21.mp4',
#  'Squat\\squat_22.mp4',
#  'Squat\\squat_23.mp4',
#  'Squat\\squat_7.mp4',
#  'Squat\\squat_8.mp4',
#  'Squat\\squat_9.mp4']

# %%
video_paths = []
for workout in actions:
    for video_file in os.listdir(workout):
        video_paths.append(f'{workout}\{video_file}')

# %%
video_paths
# Out:
# ['Bench Press\\bench press_1.mp4',
#  'Bench Press\\bench press_10.mp4',
#  'Bench Press\\bench press_11.mp4',
#  'Bench Press\\bench press_12.mp4',
#  'Bench Press\\bench press_13.mp4',
#  'Bench Press\\bench press_14.mp4',
#  'Bench Press\\bench press_15.mp4',
#  'Bench Press\\bench press_16.mp4',
#  'Bench Press\\bench press_17.mp4',
#  'Bench Press\\bench press_2.mp4',
#  'Bench Press\\bench press_3.mp4',
#  'Bench Press\\bench press_4.mp4',
#  'Bench Press\\bench press_5.mp4',
#  'Bench Press\\bench press_6.mp4',
#  'Bench Press\\bench press_7.mp4',
#  'Bench Press\\bench press_8.mp4',
#  'Bench Press\\bench press_9.mp4',
#  'PushUp\\push-up_1.mp4',
#  'PushUp\\push-up_10.mp4',
#  'PushUp\\push-up_11.mp4',
#  'PushUp\\push-up_12.mp4',
#  'PushUp\\push-up_13.mp4',
#  'PushUp\\push-up_14.mp4',
#  'PushUp\\push-up_15.mp4',
#  'PushUp\\push-up_16.mp4',
#  'PushUp\\push-up_17.mp4',
#  'PushUp\\push-up_2.mp4',
#  'PushUp\\push-up_3.mp4',
#  'PushUp\\push-up_4.mp4',
#  'PushUp\\push-up_5.mp4',
#  'PushUp\\push-up_6.mp4',
#  'PushUp\\push-up_7.mp4',
#  'PushUp\\push-up_8.mp4',
#  'PushUp\\push-up_9.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_1.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_10.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_11.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_12.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_13.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_14.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_15.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_16.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_17.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_2.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_3.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_4.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_5.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_6.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_7.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_8.mp4',
#  'Barbell Biceps Curl\\barbell biceps curl_9.mp4',
#  'Lateral Raises\\lateral raise_1.MOV',
#  'Lateral Raises\\lateral raise_10.mp4',
#  'Lateral Raises\\lateral raise_11.mp4',
#  'Lateral Raises\\lateral raise_12.mp4',
#  'Lateral Raises\\lateral raise_13.mp4',
#  'Lateral Raises\\lateral raise_14.mp4',
#  'Lateral Raises\\lateral raise_15.mp4',
#  'Lateral Raises\\lateral raise_16.mp4',
#  'Lateral Raises\\lateral raise_17.mp4',
#  'Lateral Raises\\lateral raise_2.MOV',
#  'Lateral Raises\\lateral raise_3.MOV',
#  'Lateral Raises\\lateral raise_4.MOV',
#  'Lateral Raises\\lateral raise_5.MOV',
#  'Lateral Raises\\lateral raise_6.MOV',
#  'Lateral Raises\\lateral raise_7.mp4',
#  'Lateral Raises\\lateral raise_8.mp4',
#  'Lateral Raises\\lateral raise_9.mp4',
#  'Shoulder Press\\shoulder press_1.MOV',
#  'Shoulder Press\\shoulder press_10.mp4',
#  'Shoulder Press\\shoulder press_11.mp4',
#  'Shoulder Press\\shoulder press_12.mp4',
#  'Shoulder Press\\shoulder press_13.mp4',
#  'Shoulder Press\\shoulder press_14.mp4',
#  'Shoulder Press\\shoulder press_15.mp4',
#  'Shoulder Press\\shoulder press_16.mp4',
#  'Shoulder Press\\shoulder press_17.mp4',
#  'Shoulder Press\\shoulder press_2.MOV',
#  'Shoulder Press\\shoulder press_3.MOV',
#  'Shoulder Press\\shoulder press_4.MOV',
#  'Shoulder Press\\shoulder press_5.mp4',
#  'Shoulder Press\\shoulder press_6.mp4',
#  'Shoulder Press\\shoulder press_7.mp4',
#  'Shoulder Press\\shoulder press_8.mp4',
#  'Shoulder Press\\shoulder press_9.mp4',
#  'Squat\\squat_10.mp4',
#  'Squat\\squat_11.mp4',
#  'Squat\\squat_12.mp4',
#  'Squat\\squat_13.mp4',
#  'Squat\\squat_14.mp4',
#  'Squat\\squat_15.mp4',
#  'Squat\\squat_16.mp4',
#  'Squat\\squat_17.mp4',
#  'Squat\\squat_18.mp4',
#  'Squat\\squat_19.mp4',
#  'Squat\\squat_20.mp4',
#  'Squat\\squat_21.mp4',
#  'Squat\\squat_22.mp4',
#  'Squat\\squat_23.mp4',
#  'Squat\\squat_7.mp4',
#  'Squat\\squat_8.mp4',
#  'Squat\\squat_9.mp4']

# %%
actions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3840\3502413775.py in <module>
# ----> 1 actions
#
# NameError: name 'actions' is not defined

# %%
# Assuming you have a list of video file paths
video_paths = []
counter=100
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    # Loop through actions
    for idx, action in enumerate(actions):
        # Loop through video paths
        print(action)
        print('==========')
        video_paths = []
        counter=100
        for video_file in os.listdir(action):
            video_paths.append(f'{action}\{video_file}')
        for video_path in video_paths:
            cap = cv2.VideoCapture(video_path)

            # Loop through video length (i.e., sequence length)
            for frame_num in range(sequence_length):
                # Read frame
                ret, frame = cap.read()
                if not ret:
                    break
                # Make detection
                image, results = mediapipe_detection(frame, pose)

                # Extract landmarks
                try:
                    landmarks = results.pose_landmarks.landmark
                except:
                    pass

                # Render detections
                draw_landmarks(image, results) 

                # Apply visualization logic
                if frame_num == 0: # If first frame in sequence, print that you're starting a new data collection and wait 500 ms
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)

                    cv2.putText(image, 'Collecting {} from {}'.format(action, os.path.basename(video_path)), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    # cv2.putText(image, 'Collecting {} from {}'.format(action, os.path.basename(video_path)), (15,30), 
                    #         cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)

                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting {} from {}'.format(action, os.path.basename(video_path)), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    # cv2.putText(image, 'Collecting {} from {}'.format(action, os.path.basename(video_path)), (15,30), 
                    #         cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)

                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # Export keypoints (sequence + pose landmarks)
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(counter+1), str(frame_num))
                print(npy_path)
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
            counter+=1
            cap.release()
            cv2.destroyAllWindows()
# Out:
# Bench Press
# ==========
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\101\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\102\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\103\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\104\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\105\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\106\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\107\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\108\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\109\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\110\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\111\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\112\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Bench Press\113\29
# PushUp
# ==========
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\101\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\102\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\103\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\104\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\105\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\106\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\107\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\108\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\109\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\110\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\111\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\112\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\PushUp\113\29
# Barbell Biceps Curl
# ==========
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Barbell Biceps Curl\101\13
# ...
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\104\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\105\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\106\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\107\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\108\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\109\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\110\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\111\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\112\29
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\0
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\1
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\2
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\3
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\4
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\5
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\6
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\7
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\8
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\9
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\10
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\11
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\12
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\13
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\14
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\15
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\16
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\17
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\18
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\19
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\20
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\21
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\22
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\23
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\24
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\25
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\26
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\27
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\28
# e:\openCV\lstm\Exercise_Recognition_AI\data\Squat\113\29

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Preprocess Data and Create Labels/Features

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
# Load and organize recorded training data
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):         
            # LSTM input data
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)  
            
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.shape(window)
# Out:
# (30, 132)

# %%
print(len(sequences))
# Out:
# 78

# %%
# Make sure first dimensions of arrays match
X = np.array(sequences)
y = to_categorical(labels).astype(int)
print(X.shape, y.shape)
# Out:
# (78, 30, 132) (78, 6)

# %%
# Split into training, validation, and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
print(X_train.shape, y_train.shape)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=15/90, random_state=2)
# Out:
# (70, 30, 132) (70, 6)

# %% [markdown]
# # 6. Build and Train Neural Networks

# %%
# Callbacks to be used during neural network training 
es_callback = EarlyStopping(monitor='val_loss', min_delta=5e-4, patience=10, verbose=0, mode='min')
lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=0, mode='min')
chkpt_callback = ModelCheckpoint(filepath=DATA_PATH, monitor='val_loss', verbose=0, save_best_only=True, 
                                 save_weights_only=False, mode='min', save_freq=1)

# Optimizer
opt = tensorflow.keras.optimizers.legacy.Adam(learning_rate=0.01)

# some hyperparamters
batch_size = 32
max_epochs = 500

# %% [markdown]
# ## 6a. LSTM

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-LSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
num_input_values
# Out:
# 132

# %%
lstm = Sequential()
lstm.add(LSTM(128, return_sequences=True, activation='relu', input_shape=(sequence_length, num_input_values)))
lstm.add(LSTM(256, return_sequences=True, activation='relu'))
lstm.add(LSTM(128, return_sequences=False, activation='relu'))
lstm.add(Dense(128, activation='relu'))
lstm.add(Dense(64, activation='relu'))
lstm.add(Dense(actions.shape[0], activation='softmax'))
print(lstm.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30,
- val_categorical_accuracy: 0.2500 - lr: 4.0000e-04
# Epoch 46/500
# 2/2 [==============================] - 1s 416ms/step - loss: 10.8196 - categorical_accuracy: 0.2759 - val_loss: 12.4484 - val_categorical_accuracy: 0.1667 - lr: 4.0000e-04
# Epoch 47/500
# 2/2 [==============================] - 1s 476ms/step - loss: 10.4649 - categorical_accuracy: 0.2241 - val_loss: 10.5960 - val_categorical_accuracy: 0.1667 - lr: 4.0000e-04

# %% [markdown]
# ## 6b. LSTM + Attention

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-AttnLSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
def attention_block(inputs, time_steps):
    """
    Attention layer for deep neural network
    
    """
    # Attention weights
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='softmax')(a)
    
    # Attention vector
    a_probs = Permute((2, 1), name='attention_vec')(a)
    
    # Luong's multiplicative score
    output_attention_mul = multiply([inputs, a_probs], name='attention_mul') 
    
    return output_attention_mul

# %%
HIDDEN_UNITS = 256

# Input
inputs = Input(shape=(sequence_length, num_input_values))

# Bi-LSTM
lstm_out = Bidirectional(LSTM(HIDDEN_UNITS, return_sequences=True))(inputs)

# Attention
attention_mul = attention_block(lstm_out, sequence_length)
attention_mul = Flatten()(attention_mul)

# Fully Connected Layer
x = Dense(2*HIDDEN_UNITS, activation='relu')(attention_mul)
x = Dropout(0.5)(x)

# Output
x = Dense(actions.shape[0], activation='softmax')(x)

# Bring it all together
AttnLSTM = Model(inputs=[inputs], outputs=x)
print(AttnLSTM.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30, 132)]            0         []
#
#  bidirectional (Bidirection  (None, 30, 512)              796672    ['input_1[0][0]']
#  al)
#
#  permute (Permute)           (None, 512, 30)              0         ['bidirectional[0][0]']
#
#  dense_6 (Dense)             (None, 512, 30)              930       ['permute[0][0]']
#
#  attention_vec (Permute)     (None, 30, 512)              0         ['dense_6[0][0]']
#
#  attention_mul (Multiply)    (None, 30, 512)              0         ['bidirectional[0][0]',
#                                                                      'attention_vec[0][0]']
#
#  flatten (Flatten)           (None, 15360)                0         ['attention_mul[0][0]']
#
#  dense_7 (Dense)             (None, 512)                  7864832   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 6)                    3078      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 8665512 (33.06 MB)
# Trainable params: 8665512 (33.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
AttnLSTM.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
AttnLSTM.fit(X_train, y_train, batch_size=batch_size, epochs=max_epochs, validation_data=(X_val, y_val), callbacks=callbacks)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 7s 2s/step - loss: 1.7930 - categorical_accuracy: 0.1724 - val_loss: 1.7847 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-05
# Epoch 2/500
# 2/2 [==============================] - 1s 568ms/step - loss: 1.7693 - categorical_accuracy: 0.3793 - val_loss: 1.7743 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-05
# Epoch 3/500
# 2/2 [==============================] - 1s 522ms/step - loss: 1.7565 - categorical_accuracy: 0.4655 - val_loss: 1.7666 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-05
# Epoch 4/500
# 2/2 [==============================] - 1s 549ms/step - loss: 1.7311 - categorical_accuracy: 0.4483 - val_loss: 1.7540 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-05
# Epoch 5/500
# 2/2 [==============================] - 1s 590ms/step - loss: 1.7081 - categorical_accuracy: 0.4483 - val_loss: 1.7402 - val_categorical_accuracy: 0.2500 - lr: 8.0000e
- val_categorical_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 47/500
# 2/2 [==============================] - 1s 443ms/step - loss: 0.0935 - categorical_accuracy: 0.9828 - val_loss: 0.6772 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 48/500
# 2/2 [==============================] - 1s 466ms/step - loss: 0.0909 - categorical_accuracy: 0.9655 - val_loss: 0.6781 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-05

# %%
# Model map
models = {
    'LSTM': lstm, 
    'LSTM_Attention_128HUs': AttnLSTM, 
}

# %% [markdown]
# # 7a. Save Weights

# %%
for model_name, model in models.items():
    save_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.save(save_dir)
# Out:
# c:\Users\Atharva Sankhe\anaconda3\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 7b. Load Weights

# %%
# Run model rebuild before doing this
for model_name, model in models.items():
    load_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.load_weights(load_dir)

# %% [markdown]
# # 8. Make Predictions

# %%
for model in models.values():
    res = model.predict(X_test, verbose=0)

# %% [markdown]
# # 9. Evaluations using Confusion Matrix and Accuracy

# %%
eval_results = {}
eval_results['confusion matrix'] = None
eval_results['accuracy'] = None
eval_results['precision'] = None
eval_results['recall'] = None
eval_results['f1 score'] = None

confusion_matrices = {}
classification_accuracies = {}   
precisions = {}
recalls = {}
f1_scores = {}

# %% [markdown]
# ## 9a. Confusion Matrices

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Confusion matrix
    confusion_matrices[model_name] = multilabel_confusion_matrix(ytrue, yhat)
    print(f"{model_name} confusion matrix: {os.linesep}{confusion_matrices[model_name]}")

# Collect results 
eval_results['confusion matrix'] = confusion_matrices
# Out:
# LSTM confusion matrix:
# [[[6 2]
#   [0 0]]
#
#  [[2 5]
#   [0 1]]
#
#  [[7 0]
#   [1 0]]
#
#  [[5 0]
#   [3 0]]
#
#  [[5 0]
#   [3 0]]]
# LSTM_Attention_128HUs confusion matrix:
# [[[6 1]
#   [0 1]]
#
#  [[7 0]
#   [0 1]]
#
#  [[5 0]
#   [0 3]]
#
#  [[5 0]
#   [1 2]]]

# %% [markdown]
# ## 9b. Accuracy

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Model accuracy
    classification_accuracies[model_name] = accuracy_score(ytrue, yhat)    
    print(f"{model_name} classification accuracy = {round(classification_accuracies[model_name]*100,3)}%")

# Collect results 
eval_results['accuracy'] = classification_accuracies
# Out:
# LSTM classification accuracy = 12.5%
# LSTM_Attention_128HUs classification accuracy = 87.5%

# %% [markdown]
# ## 9c. Precision, Recall, and F1 Score

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
#     Precision, recall, and f1 score
#     report = classification_report(ytrue, yhat, target_names=actions, output_dict=True)
    
#     precisions[model_name] = report['weighted avg']['precision']
#     recalls[model_name] = report['weighted avg']['recall']
#     f1_scores[model_name] = report['weighted avg']['f1-score'] 
   
#     print(f"{model_name} weighted average precision = {round(precisions[model_name],3)}")
#     print(f"{model_name} weighted average recall = {round(recalls[model_name],3)}")
#     print(f"{model_name} weighted average f1-score = {round(f1_scores[model_name],3)}\n")

# # Collect results 
# eval_results['precision'] = precisions
# eval_results['recall'] = recalls
# eval_results['f1 score'] = f1_scores

# %% [markdown]
# # 10. Choose Model to Test in Real Time

# %%
model = AttnLSTM
model_name = 'AttnLSTM'

# %% [markdown]
# # 11. Calculate Joint Angles & Count Reps

# %%
def calculate_angle(a,b,c):
    """
    Computes 3D joint angle inferred by 3 keypoints and their relative positions to one another
    
    """
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %%
def get_coordinates(landmarks, mp_pose, side, joint):
    """
    Retrieves x and y coordinates of a particular keypoint from the pose estimation model
         
     Args:
         landmarks: processed keypoints from the pose estimation model
         mp_pose: Mediapipe pose estimation model
         side: 'left' or 'right'. Denotes the side of the body of the landmark of interest.
         joint: 'shoulder', 'elbow', 'wrist', 'hip', 'knee', or 'ankle'. Denotes which body joint is associated with the landmark of interest.
    
    """
    coord = getattr(mp_pose.PoseLandmark,side.upper()+"_"+joint.upper())
    x_coord_val = landmarks[coord.value].x
    y_coord_val = landmarks[coord.value].y
    return [x_coord_val, y_coord_val]

# %%
def viz_joint_angle(image, angle, joint):
    """
    Displays the joint angle value near the joint within the image frame
    
    """
    cv2.putText(image, str(int(angle)), 
                   tuple(np.multiply(joint, [640, 480]).astype(int)), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                        )
    return

# %%
def count_reps(image, current_action, landmarks, mp_pose):
    """
    Counts repetitions of each exercise. Global count and stage (i.e., state) variables are updated within this function.
    
    """

    global curl_counter, press_counter, squat_counter, curl_stage, press_stage, squat_stage
    
    if current_action == 'Barbell Biceps Curl':
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')
        
        # calculate elbow angle
        angle = calculate_angle(shoulder, elbow, wrist)
        
        # curl counter logic
        if angle < 30:
            curl_stage = "up" 
        if angle > 140 and curl_stage =='up':
            curl_stage="down"  
            curl_counter +=1
        press_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, angle, elbow)
        
    elif current_action == 'Shoulder Press':
        
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')

        # Calculate elbow angle
        elbow_angle = calculate_angle(shoulder, elbow, wrist)
        
        # Compute distances between joints
        shoulder2elbow_dist = abs(math.dist(shoulder,elbow))
        shoulder2wrist_dist = abs(math.dist(shoulder,wrist))
        
        # Press counter logic
        if (elbow_angle > 150) and (shoulder2elbow_dist < shoulder2wrist_dist):
            press_stage = "up"
        if (elbow_angle < 90) and (shoulder2elbow_dist > shoulder2wrist_dist) and (press_stage =='up'):
            press_stage='down'
            press_counter += 1
        curl_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, elbow_angle, elbow)
        
    elif current_action == 'Squat':
        # Get coords
        # left side
        # left_shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        left_hip = get_coordinates(landmarks, mp_pose, 'left', 'hip')
        left_knee = get_coordinates(landmarks, mp_pose, 'left', 'knee')
        left_ankle = get_coordinates(landmarks, mp_pose, 'left', 'ankle')
        # right side
        # right_shoulder = get_coordinates(landmarks, mp_pose, 'right', 'shoulder')
        right_hip = get_coordinates(landmarks, mp_pose, 'right', 'hip')
        right_knee = get_coordinates(landmarks, mp_pose, 'right', 'knee')
        right_ankle = get_coordinates(landmarks, mp_pose, 'right', 'ankle')
        
        # Calculate knee angles
        left_knee_angle = calculate_angle(left_hip, left_knee, left_ankle)
        right_knee_angle = calculate_angle(right_hip, right_knee, right_ankle)
        
        # Calculate hip angles
        # left_hip_angle = calculate_angle(left_shoulder, left_hip, left_knee)
        # right_hip_angle = calculate_angle(right_shoulder, right_hip, right_knee)
        
        # Squat counter logic
        thr = 165
        # if (left_knee_angle < thr) and (right_knee_angle < thr) and (left_hip_angle < thr) and (right_hip_angle < thr):
        if (left_knee_angle < thr) and (right_knee_angle < thr):
            squat_stage = "down"
        # if (left_knee_angle > thr) and (right_knee_angle > thr) and (left_hip_angle > thr) and (right_hip_angle > thr) and (squat_stage =='down'):
        if (left_knee_angle > thr) and (right_knee_angle > thr) and  (squat_stage =='down'):
            squat_stage='up'
            squat_counter += 1
        curl_stage = None
        press_stage = None
            
        # Viz joint angles
        viz_joint_angle(image, left_knee_angle, left_knee)
        # viz_joint_angle(image, left_hip_angle, left_hip)
        
    else:
        pass

# %% [markdown]
# # 12. Test in Real Time

# %%
def prob_viz(res, actions, input_frame, colors):
    """
    This function displays the model prediction probability distribution over the set of exercise classes
    as a horizontal bar graph
    
    """
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):        
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
print("heelo")
# Out:
# heelo
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 1. New detection variables
sequence = []
predictions = []
res = []
threshold = 0.5 # minimum confidence to classify as an action/exercise
current_action = ''

# Rep counter logic variables
curl_counter = 0
press_counter = 0
squat_counter = 0
curl_stage = None
press_stage = None
squat_stage = None

# Camera object
cap = cv2.VideoCapture(0)

# Video writer object that saves a video of the real time test
fourcc = cv2.VideoWriter_fourcc('M','J','P','G') # video compression format
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

video_name = os.path.join(os.getcwd(),f"{model_name}_real_time_test.avi")
out = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*"MJPG"), FPS, (WIDTH,HEIGHT))

# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)        
        sequence.append(keypoints)      
        sequence = sequence[-sequence_length:]
              
        if len(sequence) == sequence_length:
            res = model.predict(np.expand_dims(sequence, axis=0), verbose=0)[0]           
            predictions.append(np.argmax(res))
            current_action = actions[np.argmax(res)]
            confidence = np.max(res)
            
        #3. Viz logic
            # Erase current action variable if no probability is above threshold
            if confidence < threshold:
                current_action = ''

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
            # Count reps
            try:
                landmarks = results.pose_landmarks.landmark
                count_reps(
                    image, current_action, landmarks, mp_pose)
            except:
                pass

            # Display graphical information
            cv2.rectangle(image, (0,0), (640, 40), colors[np.argmax(res)], -1)
            cv2.putText(image, 'curl ' + str(curl_counter), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'press ' + str(press_counter), (240,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'squat ' + str(squat_counter), (490,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
         
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Write to video file
        if ret == True:
            out.write(image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
# 1. New detection variables
sequence = []
predictions = []
res = []
threshold = 0.5 # minimum confidence to classify as an action/exercise
current_action = ''

# Rep counter logic variables
curl_counter = 0
press_counter = 0
squat_counter = 0
curl_stage = None
press_stage = None
squat_stage = None

# Camera object
cap = cv2.VideoCapture('squat\squat_7.mp4')

# Video writer object that saves a video of the real time test
fourcc = cv2.VideoWriter_fourcc('M','J','P','G') # video compression format
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

video_name = os.path.join(os.getcwd(),f"{model_name}_real_time_test.avi")
out = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*"MJPG"), FPS, (WIDTH,HEIGHT))

# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)        
        sequence.append(keypoints)      
        sequence = sequence[-sequence_length:]
              
        if len(sequence) == sequence_length:
            res = model.predict(np.expand_dims(sequence, axis=0), verbose=0)[0]           
            predictions.append(np.argmax(res))
            current_action = actions[np.argmax(res)]
            confidence = np.max(res)
            
        #3. Viz logic
            # Erase current action variable if no probability is above threshold
            if confidence < threshold:
                current_action = ''

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
            # Count reps
            try:
                landmarks = results.pose_landmarks.landmark
                count_reps(
                    image, current_action, landmarks, mp_pose)
            except:
                pass

            # Display graphical information
            cv2.rectangle(image, (0,0), (640, 40), colors[np.argmax(res)], -1)
            cv2.putText(image, 'curl ' + str(curl_counter), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'press ' + str(press_counter), (240,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'squat ' + str(squat_counter), (490,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
         
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Write to video file
        if ret == True:
            out.write(image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2460\2471234216.py in <module>
#      34
#      35         # Make detection
# ---> 36         image, results = mediapipe_detection(frame, pose)
#      37
#      38         # Draw landmarks
#
# ~\AppData\Local\Temp\ipykernel_2460\3186377277.py in mediapipe_detection(image, model)
#       4
#       5     """
# ----> 6     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
#       7     image.flags.writeable = False                  # Image is no longer writeable
#       8     results = model.process(image)                 # Make prediction
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
press_counter
# Out:
# 39

# %%
curl_counter

# %%
cap.release()
out.release()
cv2.destroyAllWindows()
